# %%
# %matplotlib inline

from __future__ import print_function
import matplotlib.pyplot as plt
import pyart
import numpy as np
from scipy import ndimage, signal
import time
from matplotlib.ticker import Formatter

sweep  = 0
x_lims = [0, 20]
y_lims = [0, 4]
v_min  = -15
v_max  = 15
fig_sz = [20, 10]
c_lbl  = 'Velocity (ms^-^1)'
p_data = 'velocity'
root_path = '/run/media/meso/DATA/phd/obs/radar/CP2/mdv/s_band/rhi/'
nyq       = 50

# %%
def plot_rhi(fn,subpl,c_flag,x_label,y_label):
    # read file
    # filename = '/media/meso/DATA/phd/obs/radar/CP2/mdv/s_band/rhi/20141106/031202.mdv'
    radar = pyart.io.read_mdv(fn)
    display = pyart.graph.RadarDisplay(radar)
    # plot velocity
    ax = fig.add_subplot(subpl)
    
    radar.info()
    
    
    gatefilter = pyart.correct.GateFilter(radar)
    gatefilter.exclude_below(p_data,v_min)
    gatefilter.exclude_above(p_data,v_max)
    corr_vel = pyart.correct.dealias_region_based(
        radar, vel_field='velocity', keep_original=False, 
        gatefilter = gatefilter, nyquist_vel=nyq, centered = True)
    radar.add_field('corrected_velocity', corr_vel, replace_existing = True)
    
  
    
    
#    smooth_corr_vel = np.zeros_like(corr_vel)
#    for i in range(smooth_corr_vel.shape[0]):
#        smooth_corr_vel[i,:] = \
#        pyart.correct.phase_proc.smooth_and_trim(corr_vel[i,:], 8)
#        
#    radar.add_field_like('corrected_velocity', 
#            'smooth_corrected_velocity', 
#            smooth_corr_vel, replace_existing = True)
    
    
#    display.plot_rhi('corrected_velocity_knots', sweep=sweep, 
#                     vmin=v_min, vmax=v_max, fig=fig, ax=ax,
#                     colorbar_flag=c_flag, cmap = pyart.graph.cm.BuDRd18,
#                     title = '', axislabels = (x_label,y_label))
#    display.set_limits(xlim=x_lims, ylim=y_lims)

    display.plot_rhi('corrected_velocity', sweep=sweep, 
                     vmin=v_min, vmax=v_max, fig=fig, ax=ax,
                     colorbar_flag=c_flag, cmap = pyart.graph.cm.BuDRd18,
                     title = '', axislabels = (x_label,y_label))
    display.set_limits(xlim=x_lims, ylim=y_lims)    
    
    plt.yticks([1,2,3])
    plt.xticks([0,5,10,15,20])
        
    ax.xaxis.grid(ls='-')
    ax.yaxis.grid(ls='-')
    #to do:
    
    #figure colorbar on rhs for all subplots
    #generate colormap for -10 to 15 centred on 0
    #major yticks (with numbers) at 2 and 4
    #y grid lines at 1,2,3,4
    #x axis is good!    

    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
            item.set_fontsize(20)

# %%
fig = plt.figure(figsize=fig_sz)

fn = '20141106/031202.mdv'
plot_rhi(root_path + fn,231,0,'','Altitude (km)')
fn = '20141127/050001.mdv'
plot_rhi(root_path + fn,232,0,'','')
fn = '20141209/043002.mdv'
plot_rhi(root_path + fn,233,0,'','')
fn = '20141211/025402.mdv'
plot_rhi(root_path + fn,234,0,'Range (km)','Altitude (km)')
fn = '20141217/053602.mdv'
plot_rhi(root_path + fn,235,0,'Range (km)','')
fn = '20141218/030001.mdv'
plot_rhi(root_path + fn,236,0,'Range (km)','')
#fn = '20150119/030045.mdv'
#plot_rhi(root_path + fn,326)

plt.savefig('tmp/CP2_seabreezes.png', dpi=200)
# Out:
# altitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: meters
# 	long_name: Altitude
# 	standard_name: Altitude
# 	positive: up
# altitude_agl: None
# antenna_transition: None
# azimuth:
# 	data: <ndarray of type: float64 and shape: (386,)>
# 	comment: Azimuth of antenna relative to true north
# 	long_name: azimuth_angle_from_true_north
# 	standard_name: beam_azimuth_angle
# 	units: degrees
# 	axis: radial_azimuth_coordinate
# elevation:
# 	data: <ndarray of type: float64 and shape: (386,)>
# 	comment: Elevation of antenna relative to the horizontal plane
# 	long_name: elevation_angle_from_horizontal_plane
# 	standard_name: beam_elevation_angle
# 	units: degrees
# 	axis: radial_elevation_coordinate
# fields:
# 	differential_phase:
# 		data: <ndarray of type: float32 and shape: (386, 950)>
# 		long_name: Differential phase (PhiDP)
# 		valid_min: -180.0
# 		_FillValue: -9999.0
# 		units: degrees
# 		valid_max: 180.0
# 		standard_name: differential_phase_hv
# 		coordinates: elevation azimuth range
# 	cross_correlation_ratio:
# 		data: <ndarray of type: float32 and shape: (386, 950)>
# 		long_name: Cross correlation ratio (RHOHV)
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: cross_correlation_ratio_hv
# 		coordinates: elevation azimuth range
# 	normalized_coherent_power:
# 		data: <ndarray of type: float32 and shape: (386, 950)>
# 		comment: Also know as signal quality index (SQI)
# 		long_name: Normalized coherent power
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: normalized_coherent_power
# 		coordinates: elevation azimuth range
# 	spectrum_width:
# 		data: <ndarray of type: float32 and shape: (386, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Doppler spectrum width
# 		standard_name: doppler_spectrum_width
# 		units: meters_per_second
# 	reflectivity:
# 		data: <ndarray of type: float32 and shape: (386, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Reflectivity
# 		standard_name: equivalent_reflectivity_factor
# 		units: dBZ
# 	differential_reflectivity:
# 		data: <ndarray of type: float32 and shape: (386, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Differential reflectivity
# 		standard_name: log_differential_reflectivity_hv
# 		units: dB
# 	specific_differential_phase:
# 		data: <ndarray of type: float32 and shape: (386, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Specific differential phase (KDP)
# 		standard_name: specific_differential_phase_hv
# 		units: degrees/km
# 	velocity:
# 		data: <ndarray of type: float32 and shape: (386, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Mean dopper velocity
# 		standard_name: radial_velocity_of_scatterers_away_from_instrument
# 		units: meters_per_second
# fixed_angle:
# 	data: <ndarray of type: float32 and shape: (2,)>
# 	units: degrees
# 	long_name: Target angle for sweep
# 	standard_name: target_fixed_angle
# instrument_parameters:
# 	radar_beam_width_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width H polarization
# 	unambiguous_range:
# 		data: <ndarray of type: float32 and shape: (386,)>
# 		units: meters
# 		meta_group: instrument_parameters
# 		comments: Unambiguous range
# 		long_name: Unambiguous range
# 	prt:
# 		data: <ndarray of type: float32 and shape: (386,)>
# 		units: seconds
# 		meta_group: instrument_parameters
# 		comments: Pulse repetition time. For staggered prt, also see prt_ratio.
# 		long_name: Pulse repetition time
# 	nyquist_velocity:
# 		data: <ndarray of type: float32 and shape: (386,)>
# 		units: meters_per_second
# 		meta_group: instrument_parameters
# 		comments: Unambiguous velocity
# 		long_name: Nyquist velocity
# 	prt_mode:
# 		data: <ndarray of type: |S5 and shape: (2,)>
# 		units: unitless
# 		meta_group: instrument_parameters
# 		comments: Pulsing mode Options are: "fixed", "staggered", "dual". Assumed "fixed" if missing.
# 		long_name: Pulsing mode
# 	radar_beam_width_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width V polarization
# latitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_north
# 	long_name: Latitude
# 	standard_name: Latitude
# longitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_east
# 	long_name: Longitude
# 	standard_name: Longitude
# nsweeps: 2
# ngates: 950
# nrays: 386
# radar_calibration: None
# range:
# 	data: <ndarray of type: float32 and shape: (950,)>
# 	comment: Coordinate variable for range. Range to center of each bin.
# 	long_name: range_to_measurement_volume
# 	standard_name: projection_range_coordinate
# 	meters_to_center_of_first_gate: 0.0
# 	meters_between_gates: 150.0
# 	units: meters
# 	spacing_is_constant: true
# 	axis: radial_range_coordinate
# scan_rate: None
# scan_type: rhi
# sweep_end_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of last ray in sweep, 0-based
# sweep_mode:
# 	data: <ndarray of type: |S3 and shape: (2,)>
# 	units: unitless
# 	long_name: Sweep mode
# 	standard_name: sweep_mode
# 	comment: Options are: "sector", "coplane", "rhi", "vertical_pointing", "idle", "azimuth_surveillance", "elevation_surveillance", "sunscan", "pointing", "manual_ppi", "manual_rhi"
# sweep_number:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Sweep number
# 	standard_name: sweep_number
# sweep_start_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of first ray in sweep, 0-based
# target_scan_rate: None
# time:
# 	data: <ndarray of type: float64 and shape: (386,)>
# 	comment: Coordinate variable for time. Time at the center of each ray, in fractional seconds since the global variable time_coverage_start
# 	long_name: time_in_seconds_since_volume_start
# 	standard_name: time
# 	units: seconds since 2014-11-06T03:11:41Z
# 	calendar: gregorian
# metadata:
# 	comment:
# 	title:
# 	Conventions: CF/Radial instrument_parameters
# 	source: MDV radar volume file created by Dsr2Vol.
# 	version: 1.3
# 	references:
# 	instrument_name: CP2, Redbank Plains, Piraq IQ data.
# 	institution:
# 	history:
# altitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: meters
# 	long_name: Altitude
# 	standard_name: Altitude
# 	positive: up
# altitude_agl: None
# antenna_transition: None
# azimuth:
# 	data: <ndarray of type: float64 and shape: (388,)>
# 	comment: Azimuth of antenna relative to true north
# 	long_name: azimuth_angle_from_true_north
# 	standard_name: beam_azimuth_angle
# 	units: degrees
# 	axis: radial_azimuth_coordinate
# elevation:
# 	data: <ndarray of type: float64 and shape: (388,)>
# 	comment: Elevation of antenna relative to the horizontal plane
# 	long_name: elevation_angle_from_horizontal_plane
# 	standard_name: beam_elevation_angle
# 	units: degrees
# 	axis: radial_elevation_coordinate
# fields:
# 	differential_phase:
# 		data: <ndarray of type: float32 and shape: (388, 950)>
# 		long_name: Differential phase (PhiDP)
# 		valid_min: -180.0
# 		_FillValue: -9999.0
# 		units: degrees
# 		valid_max: 180.0
# 		standard_name: differential_phase_hv
# 		coordinates: elevation azimuth range
# 	cross_correlation_ratio:
# 		data: <ndarray of type: float32 and shape: (388, 950)>
# 		long_name: Cross correlation ratio (RHOHV)
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: cross_correlation_ratio_hv
# 		coordinates: elevation azimuth range
# 	normalized_coherent_power:
# 		data: <ndarray of type: float32 and shape: (388, 950)>
# 		comment: Also know as signal quality index (SQI)
# 		long_name: Normalized coherent power
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: normalized_coherent_power
# 		coordinates: elevation azimuth range
# 	spectrum_width:
# 		data: <ndarray of type: float32 and shape: (388, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Doppler spectrum width
# 		standard_name: doppler_spectrum_width
# 		units: meters_per_second
# 	reflectivity:
# 		data: <ndarray of type: float32 and shape: (388, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Reflectivity
# 		standard_name: equivalent_reflectivity_factor
# 		units: dBZ
# 	differential_reflectivity:
# 		data: <ndarray of type: float32 and shape: (388, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Differential reflectivity
# 		standard_name: log_differential_reflectivity_hv
# 		units: dB
# 	specific_differential_phase:
# 		data: <ndarray of type: float32 and shape: (388, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Specific differential phase (KDP)
# 		standard_name: specific_differential_phase_hv
# 		units: degrees/km
# 	velocity:
# 		data: <ndarray of type: float32 and shape: (388, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Mean dopper velocity
# 		standard_name: radial_velocity_of_scatterers_away_from_instrument
# 		units: meters_per_second
# fixed_angle:
# 	data: <ndarray of type: float32 and shape: (2,)>
# 	units: degrees
# 	long_name: Target angle for sweep
# 	standard_name: target_fixed_angle
# instrument_parameters:
# 	radar_beam_width_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width H polarization
# 	unambiguous_range:
# 		data: <ndarray of type: float32 and shape: (388,)>
# 		units: meters
# 		meta_group: instrument_parameters
# 		comments: Unambiguous range
# 		long_name: Unambiguous range
# 	prt:
# 		data: <ndarray of type: float32 and shape: (388,)>
# 		units: seconds
# 		meta_group: instrument_parameters
# 		comments: Pulse repetition time. For staggered prt, also see prt_ratio.
# 		long_name: Pulse repetition time
# 	nyquist_velocity:
# 		data: <ndarray of type: float32 and shape: (388,)>
# 		units: meters_per_second
# 		meta_group: instrument_parameters
# 		comments: Unambiguous velocity
# 		long_name: Nyquist velocity
# 	prt_mode:
# 		data: <ndarray of type: |S5 and shape: (2,)>
# 		units: unitless
# 		meta_group: instrument_parameters
# 		comments: Pulsing mode Options are: "fixed", "staggered", "dual". Assumed "fixed" if missing.
# 		long_name: Pulsing mode
# 	radar_beam_width_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width V polarization
# latitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_north
# 	long_name: Latitude
# 	standard_name: Latitude
# longitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_east
# 	long_name: Longitude
# 	standard_name: Longitude
# nsweeps: 2
# ngates: 950
# nrays: 388
# radar_calibration: None
# range:
# 	data: <ndarray of type: float32 and shape: (950,)>
# 	comment: Coordinate variable for range. Range to center of each bin.
# 	long_name: range_to_measurement_volume
# 	standard_name: projection_range_coordinate
# 	meters_to_center_of_first_gate: 0.0
# 	meters_between_gates: 150.0
# 	units: meters
# 	spacing_is_constant: true
# 	axis: radial_range_coordinate
# scan_rate: None
# scan_type: rhi
# sweep_end_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of last ray in sweep, 0-based
# sweep_mode:
# 	data: <ndarray of type: |S3 and shape: (2,)>
# 	units: unitless
# 	long_name: Sweep mode
# 	standard_name: sweep_mode
# 	comment: Options are: "sector", "coplane", "rhi", "vertical_pointing", "idle", "azimuth_surveillance", "elevation_surveillance", "sunscan", "pointing", "manual_ppi", "manual_rhi"
# sweep_number:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Sweep number
# 	standard_name: sweep_number
# sweep_start_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of first ray in sweep, 0-based
# target_scan_rate: None
# time:
# 	data: <ndarray of type: float64 and shape: (388,)>
# 	comment: Coordinate variable for time. Time at the center of each ray, in fractional seconds since the global variable time_coverage_start
# 	long_name: time_in_seconds_since_volume_start
# 	standard_name: time
# 	units: seconds since 2014-11-27T04:59:34Z
# 	calendar: gregorian
# metadata:
# 	comment:
# 	title:
# 	Conventions: CF/Radial instrument_parameters
# 	source: MDV radar volume file created by Dsr2Vol.
# 	version: 1.3
# 	references:
# 	instrument_name: CP2, Redbank Plains, Piraq IQ data.
# 	institution:
# 	history:
# altitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: meters
# 	long_name: Altitude
# 	standard_name: Altitude
# 	positive: up
# altitude_agl: None
# antenna_transition: None
# azimuth:
# 	data: <ndarray of type: float64 and shape: (428,)>
# 	comment: Azimuth of antenna relative to true north
# 	long_name: azimuth_angle_from_true_north
# 	standard_name: beam_azimuth_angle
# 	units: degrees
# 	axis: radial_azimuth_coordinate
# elevation:
# 	data: <ndarray of type: float64 and shape: (428,)>
# 	comment: Elevation of antenna relative to the horizontal plane
# 	long_name: elevation_angle_from_horizontal_plane
# 	standard_name: beam_elevation_angle
# 	units: degrees
# 	axis: radial_elevation_coordinate
# fields:
# 	differential_phase:
# 		data: <ndarray of type: float32 and shape: (428, 950)>
# 		long_name: Differential phase (PhiDP)
# 		valid_min: -180.0
# 		_FillValue: -9999.0
# 		units: degrees
# 		valid_max: 180.0
# 		standard_name: differential_phase_hv
# 		coordinates: elevation azimuth range
# 	cross_correlation_ratio:
# 		data: <ndarray of type: float32 and shape: (428, 950)>
# 		long_name: Cross correlation ratio (RHOHV)
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: cross_correlation_ratio_hv
# 		coordinates: elevation azimuth range
# 	normalized_coherent_power:
# 		data: <ndarray of type: float32 and shape: (428, 950)>
# 		comment: Also know as signal quality index (SQI)
# 		long_name: Normalized coherent power
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: normalized_coherent_power
# 		coordinates: elevation azimuth range
# 	spectrum_width:
# 		data: <ndarray of type: float32 and shape: (428, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Doppler spectrum width
# 		standard_name: doppler_spectrum_width
# 		units: meters_per_second
# 	reflectivity:
# 		data: <ndarray of type: float32 and shape: (428, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Reflectivity
# 		standard_name: equivalent_reflectivity_factor
# 		units: dBZ
# 	differential_reflectivity:
# 		data: <ndarray of type: float32 and shape: (428, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Differential reflectivity
# 		standard_name: log_differential_reflectivity_hv
# 		units: dB
# 	specific_differential_phase:
# 		data: <ndarray of type: float32 and shape: (428, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Specific differential phase (KDP)
# 		standard_name: specific_differential_phase_hv
# 		units: degrees/km
# 	velocity:
# 		data: <ndarray of type: float32 and shape: (428, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Mean dopper velocity
# 		standard_name: radial_velocity_of_scatterers_away_from_instrument
# 		units: meters_per_second
# fixed_angle:
# 	data: <ndarray of type: float32 and shape: (2,)>
# 	units: degrees
# 	long_name: Target angle for sweep
# 	standard_name: target_fixed_angle
# instrument_parameters:
# 	radar_beam_width_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width H polarization
# 	unambiguous_range:
# 		data: <ndarray of type: float32 and shape: (428,)>
# 		units: meters
# 		meta_group: instrument_parameters
# 		comments: Unambiguous range
# 		long_name: Unambiguous range
# 	prt:
# 		data: <ndarray of type: float32 and shape: (428,)>
# 		units: seconds
# 		meta_group: instrument_parameters
# 		comments: Pulse repetition time. For staggered prt, also see prt_ratio.
# 		long_name: Pulse repetition time
# 	nyquist_velocity:
# 		data: <ndarray of type: float32 and shape: (428,)>
# 		units: meters_per_second
# 		meta_group: instrument_parameters
# 		comments: Unambiguous velocity
# 		long_name: Nyquist velocity
# 	prt_mode:
# 		data: <ndarray of type: |S5 and shape: (2,)>
# 		units: unitless
# 		meta_group: instrument_parameters
# 		comments: Pulsing mode Options are: "fixed", "staggered", "dual". Assumed "fixed" if missing.
# 		long_name: Pulsing mode
# 	radar_beam_width_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width V polarization
# latitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_north
# 	long_name: Latitude
# 	standard_name: Latitude
# longitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_east
# 	long_name: Longitude
# 	standard_name: Longitude
# nsweeps: 2
# ngates: 950
# nrays: 428
# radar_calibration: None
# range:
# 	data: <ndarray of type: float32 and shape: (950,)>
# 	comment: Coordinate variable for range. Range to center of each bin.
# 	long_name: range_to_measurement_volume
# 	standard_name: projection_range_coordinate
# 	meters_to_center_of_first_gate: 0.0
# 	meters_between_gates: 150.0
# 	units: meters
# 	spacing_is_constant: true
# 	axis: radial_range_coordinate
# scan_rate: None
# scan_type: rhi
# sweep_end_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of last ray in sweep, 0-based
# sweep_mode:
# 	data: <ndarray of type: |S3 and shape: (2,)>
# 	units: unitless
# 	long_name: Sweep mode
# 	standard_name: sweep_mode
# 	comment: Options are: "sector", "coplane", "rhi", "vertical_pointing", "idle", "azimuth_surveillance", "elevation_surveillance", "sunscan", "pointing", "manual_ppi", "manual_rhi"
# sweep_number:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Sweep number
# 	standard_name: sweep_number
# sweep_start_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of first ray in sweep, 0-based
# target_scan_rate: None
# time:
# 	data: <ndarray of type: float64 and shape: (428,)>
# 	comment: Coordinate variable for time. Time at the center of each ray, in fractional seconds since the global variable time_coverage_start
# 	long_name: time_in_seconds_since_volume_start
# 	standard_name: time
# 	units: seconds since 2014-12-09T04:29:37Z
# 	calendar: gregorian
# metadata:
# 	comment:
# 	title:
# 	Conventions: CF/Radial instrument_parameters
# 	source: MDV radar volume file created by Dsr2Vol.
# 	version: 1.3
# 	references:
# 	instrument_name: CP2, Redbank Plains, Piraq IQ data.
# 	institution:
# 	history:
# altitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: meters
# 	long_name: Altitude
# 	standard_name: Altitude
# 	positive: up
# altitude_agl: None
# antenna_transition: None
# azimuth:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Azimuth of antenna relative to true north
# 	long_name: azimuth_angle_from_true_north
# 	standard_name: beam_azimuth_angle
# 	units: degrees
# 	axis: radial_azimuth_coordinate
# elevation:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Elevation of antenna relative to the horizontal plane
# 	long_name: elevation_angle_from_horizontal_plane
# 	standard_name: beam_elevation_angle
# 	units: degrees
# 	axis: radial_elevation_coordinate
# fields:
# 	differential_phase:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		long_name: Differential phase (PhiDP)
# 		valid_min: -180.0
# 		_FillValue: -9999.0
# 		units: degrees
# 		valid_max: 180.0
# 		standard_name: differential_phase_hv
# 		coordinates: elevation azimuth range
# 	cross_correlation_ratio:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		long_name: Cross correlation ratio (RHOHV)
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: cross_correlation_ratio_hv
# 		coordinates: elevation azimuth range
# 	normalized_coherent_power:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		comment: Also know as signal quality index (SQI)
# 		long_name: Normalized coherent power
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: normalized_coherent_power
# 		coordinates: elevation azimuth range
# 	spectrum_width:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Doppler spectrum width
# 		standard_name: doppler_spectrum_width
# 		units: meters_per_second
# 	reflectivity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Reflectivity
# 		standard_name: equivalent_reflectivity_factor
# 		units: dBZ
# 	differential_reflectivity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Differential reflectivity
# 		standard_name: log_differential_reflectivity_hv
# 		units: dB
# 	specific_differential_phase:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Specific differential phase (KDP)
# 		standard_name: specific_differential_phase_hv
# 		units: degrees/km
# 	velocity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Mean dopper velocity
# 		standard_name: radial_velocity_of_scatterers_away_from_instrument
# 		units: meters_per_second
# fixed_angle:
# 	data: <ndarray of type: float32 and shape: (2,)>
# 	units: degrees
# 	long_name: Target angle for sweep
# 	standard_name: target_fixed_angle
# instrument_parameters:
# 	radar_beam_width_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width H polarization
# 	unambiguous_range:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: meters
# 		meta_group: instrument_parameters
# 		comments: Unambiguous range
# 		long_name: Unambiguous range
# 	prt:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: seconds
# 		meta_group: instrument_parameters
# 		comments: Pulse repetition time. For staggered prt, also see prt_ratio.
# 		long_name: Pulse repetition time
# 	nyquist_velocity:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: meters_per_second
# 		meta_group: instrument_parameters
# 		comments: Unambiguous velocity
# 		long_name: Nyquist velocity
# 	prt_mode:
# 		data: <ndarray of type: |S5 and shape: (2,)>
# 		units: unitless
# 		meta_group: instrument_parameters
# 		comments: Pulsing mode Options are: "fixed", "staggered", "dual". Assumed "fixed" if missing.
# 		long_name: Pulsing mode
# 	radar_beam_width_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width V polarization
# latitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_north
# 	long_name: Latitude
# 	standard_name: Latitude
# longitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_east
# 	long_name: Longitude
# 	standard_name: Longitude
# nsweeps: 2
# ngates: 950
# nrays: 426
# radar_calibration: None
# range:
# 	data: <ndarray of type: float32 and shape: (950,)>
# 	comment: Coordinate variable for range. Range to center of each bin.
# 	long_name: range_to_measurement_volume
# 	standard_name: projection_range_coordinate
# 	meters_to_center_of_first_gate: 0.0
# 	meters_between_gates: 150.0
# 	units: meters
# 	spacing_is_constant: true
# 	axis: radial_range_coordinate
# scan_rate: None
# scan_type: rhi
# sweep_end_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of last ray in sweep, 0-based
# sweep_mode:
# 	data: <ndarray of type: |S3 and shape: (2,)>
# 	units: unitless
# 	long_name: Sweep mode
# 	standard_name: sweep_mode
# 	comment: Options are: "sector", "coplane", "rhi", "vertical_pointing", "idle", "azimuth_surveillance", "elevation_surveillance", "sunscan", "pointing", "manual_ppi", "manual_rhi"
# sweep_number:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Sweep number
# 	standard_name: sweep_number
# sweep_start_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of first ray in sweep, 0-based
# target_scan_rate: None
# time:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Coordinate variable for time. Time at the center of each ray, in fractional seconds since the global variable time_coverage_start
# 	long_name: time_in_seconds_since_volume_start
# 	standard_name: time
# 	units: seconds since 2014-12-11T02:53:36Z
# 	calendar: gregorian
# metadata:
# 	comment:
# 	title:
# 	Conventions: CF/Radial instrument_parameters
# 	source: MDV radar volume file created by Dsr2Vol.
# 	version: 1.3
# 	references:
# 	instrument_name: CP2, Redbank Plains, Piraq IQ data.
# 	institution:
# 	history:
# altitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: meters
# 	long_name: Altitude
# 	standard_name: Altitude
# 	positive: up
# altitude_agl: None
# antenna_transition: None
# azimuth:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Azimuth of antenna relative to true north
# 	long_name: azimuth_angle_from_true_north
# 	standard_name: beam_azimuth_angle
# 	units: degrees
# 	axis: radial_azimuth_coordinate
# elevation:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Elevation of antenna relative to the horizontal plane
# 	long_name: elevation_angle_from_horizontal_plane
# 	standard_name: beam_elevation_angle
# 	units: degrees
# 	axis: radial_elevation_coordinate
# fields:
# 	differential_phase:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		long_name: Differential phase (PhiDP)
# 		valid_min: -180.0
# 		_FillValue: -9999.0
# 		units: degrees
# 		valid_max: 180.0
# 		standard_name: differential_phase_hv
# 		coordinates: elevation azimuth range
# 	cross_correlation_ratio:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		long_name: Cross correlation ratio (RHOHV)
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: cross_correlation_ratio_hv
# 		coordinates: elevation azimuth range
# 	normalized_coherent_power:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		comment: Also know as signal quality index (SQI)
# 		long_name: Normalized coherent power
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: normalized_coherent_power
# 		coordinates: elevation azimuth range
# 	spectrum_width:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Doppler spectrum width
# 		standard_name: doppler_spectrum_width
# 		units: meters_per_second
# 	reflectivity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Reflectivity
# 		standard_name: equivalent_reflectivity_factor
# 		units: dBZ
# 	differential_reflectivity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Differential reflectivity
# 		standard_name: log_differential_reflectivity_hv
# 		units: dB
# 	specific_differential_phase:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Specific differential phase (KDP)
# 		standard_name: specific_differential_phase_hv
# 		units: degrees/km
# 	velocity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Mean dopper velocity
# 		standard_name: radial_velocity_of_scatterers_away_from_instrument
# 		units: meters_per_second
# fixed_angle:
# 	data: <ndarray of type: float32 and shape: (2,)>
# 	units: degrees
# 	long_name: Target angle for sweep
# 	standard_name: target_fixed_angle
# instrument_parameters:
# 	radar_beam_width_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width H polarization
# 	unambiguous_range:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: meters
# 		meta_group: instrument_parameters
# 		comments: Unambiguous range
# 		long_name: Unambiguous range
# 	prt:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: seconds
# 		meta_group: instrument_parameters
# 		comments: Pulse repetition time. For staggered prt, also see prt_ratio.
# 		long_name: Pulse repetition time
# 	nyquist_velocity:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: meters_per_second
# 		meta_group: instrument_parameters
# 		comments: Unambiguous velocity
# 		long_name: Nyquist velocity
# 	prt_mode:
# 		data: <ndarray of type: |S5 and shape: (2,)>
# 		units: unitless
# 		meta_group: instrument_parameters
# 		comments: Pulsing mode Options are: "fixed", "staggered", "dual". Assumed "fixed" if missing.
# 		long_name: Pulsing mode
# 	radar_beam_width_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width V polarization
# latitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_north
# 	long_name: Latitude
# 	standard_name: Latitude
# longitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_east
# 	long_name: Longitude
# 	standard_name: Longitude
# nsweeps: 2
# ngates: 950
# nrays: 426
# radar_calibration: None
# range:
# 	data: <ndarray of type: float32 and shape: (950,)>
# 	comment: Coordinate variable for range. Range to center of each bin.
# 	long_name: range_to_measurement_volume
# 	standard_name: projection_range_coordinate
# 	meters_to_center_of_first_gate: 0.0
# 	meters_between_gates: 150.0
# 	units: meters
# 	spacing_is_constant: true
# 	axis: radial_range_coordinate
# scan_rate: None
# scan_type: rhi
# sweep_end_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of last ray in sweep, 0-based
# sweep_mode:
# 	data: <ndarray of type: |S3 and shape: (2,)>
# 	units: unitless
# 	long_name: Sweep mode
# 	standard_name: sweep_mode
# 	comment: Options are: "sector", "coplane", "rhi", "vertical_pointing", "idle", "azimuth_surveillance", "elevation_surveillance", "sunscan", "pointing", "manual_ppi", "manual_rhi"
# sweep_number:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Sweep number
# 	standard_name: sweep_number
# sweep_start_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of first ray in sweep, 0-based
# target_scan_rate: None
# time:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Coordinate variable for time. Time at the center of each ray, in fractional seconds since the global variable time_coverage_start
# 	long_name: time_in_seconds_since_volume_start
# 	standard_name: time
# 	units: seconds since 2014-12-17T05:35:36Z
# 	calendar: gregorian
# metadata:
# 	comment:
# 	title:
# 	Conventions: CF/Radial instrument_parameters
# 	source: MDV radar volume file created by Dsr2Vol.
# 	version: 1.3
# 	references:
# 	instrument_name: CP2, Redbank Plains, Piraq IQ data.
# 	institution:
# 	history:
# altitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: meters
# 	long_name: Altitude
# 	standard_name: Altitude
# 	positive: up
# altitude_agl: None
# antenna_transition: None
# azimuth:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Azimuth of antenna relative to true north
# 	long_name: azimuth_angle_from_true_north
# 	standard_name: beam_azimuth_angle
# 	units: degrees
# 	axis: radial_azimuth_coordinate
# elevation:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Elevation of antenna relative to the horizontal plane
# 	long_name: elevation_angle_from_horizontal_plane
# 	standard_name: beam_elevation_angle
# 	units: degrees
# 	axis: radial_elevation_coordinate
# fields:
# 	differential_phase:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		long_name: Differential phase (PhiDP)
# 		valid_min: -180.0
# 		_FillValue: -9999.0
# 		units: degrees
# 		valid_max: 180.0
# 		standard_name: differential_phase_hv
# 		coordinates: elevation azimuth range
# 	cross_correlation_ratio:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		long_name: Cross correlation ratio (RHOHV)
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: cross_correlation_ratio_hv
# 		coordinates: elevation azimuth range
# 	normalized_coherent_power:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		comment: Also know as signal quality index (SQI)
# 		long_name: Normalized coherent power
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: normalized_coherent_power
# 		coordinates: elevation azimuth range
# 	spectrum_width:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Doppler spectrum width
# 		standard_name: doppler_spectrum_width
# 		units: meters_per_second
# 	reflectivity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Reflectivity
# 		standard_name: equivalent_reflectivity_factor
# 		units: dBZ
# 	differential_reflectivity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Differential reflectivity
# 		standard_name: log_differential_reflectivity_hv
# 		units: dB
# 	specific_differential_phase:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Specific differential phase (KDP)
# 		standard_name: specific_differential_phase_hv
# 		units: degrees/km
# 	velocity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Mean dopper velocity
# 		standard_name: radial_velocity_of_scatterers_away_from_instrument
# 		units: meters_per_second
# fixed_angle:
# 	data: <ndarray of type: float32 and shape: (2,)>
# 	units: degrees
# 	long_name: Target angle for sweep
# 	standard_name: target_fixed_angle
# instrument_parameters:
# 	radar_beam_width_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width H polarization
# 	unambiguous_range:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: meters
# 		meta_group: instrument_parameters
# 		comments: Unambiguous range
# 		long_name: Unambiguous range
# 	prt:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: seconds
# 		meta_group: instrument_parameters
# 		comments: Pulse repetition time. For staggered prt, also see prt_ratio.
# 		long_name: Pulse repetition time
# 	nyquist_velocity:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: meters_per_second
# 		meta_group: instrument_parameters
# 		comments: Unambiguous velocity
# 		long_name: Nyquist velocity
# 	prt_mode:
# 		data: <ndarray of type: |S5 and shape: (2,)>
# 		units: unitless
# 		meta_group: instrument_parameters
# 		comments: Pulsing mode Options are: "fixed", "staggered", "dual". Assumed "fixed" if missing.
# 		long_name: Pulsing mode
# 	radar_beam_width_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width V polarization
# latitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_north
# 	long_name: Latitude
# 	standard_name: Latitude
# longitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_east
# 	long_name: Longitude
# 	standard_name: Longitude
# nsweeps: 2
# ngates: 950
# nrays: 426
# radar_calibration: None
# range:
# 	data: <ndarray of type: float32 and shape: (950,)>
# 	comment: Coordinate variable for range. Range to center of each bin.
# 	long_name: range_to_measurement_volume
# 	standard_name: projection_range_coordinate
# 	meters_to_center_of_first_gate: 0.0
# 	meters_between_gates: 150.0
# 	units: meters
# 	spacing_is_constant: true
# 	axis: radial_range_coordinate
# scan_rate: None
# scan_type: rhi
# sweep_end_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of last ray in sweep, 0-based
# sweep_mode:
# 	data: <ndarray of type: |S3 and shape: (2,)>
# 	units: unitless
# 	long_name: Sweep mode
# 	standard_name: sweep_mode
# 	comment: Options are: "sector", "coplane", "rhi", "vertical_pointing", "idle", "azimuth_surveillance", "elevation_surveillance", "sunscan", "pointing", "manual_ppi", "manual_rhi"
# sweep_number:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Sweep number
# 	standard_name: sweep_number
# sweep_start_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of first ray in sweep, 0-based
# target_scan_rate: None
# time:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Coordinate variable for time. Time at the center of each ray, in fractional seconds since the global variable time_coverage_start
# 	long_name: time_in_seconds_since_volume_start
# 	standard_name: time
# 	units: seconds since 2014-12-18T02:59:36Z
# 	calendar: gregorian
# metadata:
# 	comment:
# 	title:
# 	Conventions: CF/Radial instrument_parameters
# 	source: MDV radar volume file created by Dsr2Vol.
# 	version: 1.3
# 	references:
# 	instrument_name: CP2, Redbank Plains, Piraq IQ data.
# 	institution:
# 	history:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-4c23023bfbe2> in <module>()
#      16 #plot_rhi(root_path + fn,326)
#      17
# ---> 18 plt.savefig('tmp/CP2_seabreezes.png', dpi=200)
#
# /home/meso/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     686 def savefig(*args, **kwargs):
#     687     fig = gcf()
# --> 688     res = fig.savefig(*args, **kwargs)
#     689     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     690     return res
#
# /home/meso/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, *args, **kwargs)
#    1563             self.set_frameon(frameon)
#    1564
# -> 1565         self.canvas.print_figure(*args, **kwargs)
#    1566
#    1567         if frameon:
#
# /home/meso/anaconda2/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2230                 orientation=orientation,
#    2231                 bbox_inches_restore=_bbox_inches_restore,
# -> 2232                 **kwargs)
#    2233         finally:
#    2234             if bbox_inches and restore_bbox:
#
# /home/meso/anaconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     530         renderer.dpi = self.figure.dpi
#     531         if is_string_like(filename_or_obj):
# --> 532             filename_or_obj = open(filename_or_obj, 'wb')
#     533             close = True
#     534         else:
#
# IOError: [Errno 2] No such file or directory: 'tmp/CP2_seabreezes.png'

# %%
fig = plt.figure(figsize=fig_sz)
fn = '20141218/030001.mdv'
plot_rhi(root_path + fn,111,1,'','')
plt.savefig('tmp/CP2_seabreezes_cmap.png', dpi=200)
# Out:
# altitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: meters
# 	long_name: Altitude
# 	standard_name: Altitude
# 	positive: up
# altitude_agl: None
# antenna_transition: None
# azimuth:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Azimuth of antenna relative to true north
# 	long_name: azimuth_angle_from_true_north
# 	standard_name: beam_azimuth_angle
# 	units: degrees
# 	axis: radial_azimuth_coordinate
# elevation:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Elevation of antenna relative to the horizontal plane
# 	long_name: elevation_angle_from_horizontal_plane
# 	standard_name: beam_elevation_angle
# 	units: degrees
# 	axis: radial_elevation_coordinate
# fields:
# 	differential_phase:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		long_name: Differential phase (PhiDP)
# 		valid_min: -180.0
# 		_FillValue: -9999.0
# 		units: degrees
# 		valid_max: 180.0
# 		standard_name: differential_phase_hv
# 		coordinates: elevation azimuth range
# 	cross_correlation_ratio:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		long_name: Cross correlation ratio (RHOHV)
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: cross_correlation_ratio_hv
# 		coordinates: elevation azimuth range
# 	normalized_coherent_power:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		comment: Also know as signal quality index (SQI)
# 		long_name: Normalized coherent power
# 		valid_min: 0.0
# 		_FillValue: -9999.0
# 		units: ratio
# 		valid_max: 1.0
# 		standard_name: normalized_coherent_power
# 		coordinates: elevation azimuth range
# 	spectrum_width:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Doppler spectrum width
# 		standard_name: doppler_spectrum_width
# 		units: meters_per_second
# 	reflectivity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Reflectivity
# 		standard_name: equivalent_reflectivity_factor
# 		units: dBZ
# 	differential_reflectivity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Differential reflectivity
# 		standard_name: log_differential_reflectivity_hv
# 		units: dB
# 	specific_differential_phase:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Specific differential phase (KDP)
# 		standard_name: specific_differential_phase_hv
# 		units: degrees/km
# 	velocity:
# 		data: <ndarray of type: float32 and shape: (426, 950)>
# 		_FillValue: -9999.0
# 		coordinates: elevation azimuth range
# 		long_name: Mean dopper velocity
# 		standard_name: radial_velocity_of_scatterers_away_from_instrument
# 		units: meters_per_second
# fixed_angle:
# 	data: <ndarray of type: float32 and shape: (2,)>
# 	units: degrees
# 	long_name: Target angle for sweep
# 	standard_name: target_fixed_angle
# instrument_parameters:
# 	radar_beam_width_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width H polarization
# 	unambiguous_range:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: meters
# 		meta_group: instrument_parameters
# 		comments: Unambiguous range
# 		long_name: Unambiguous range
# 	prt:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: seconds
# 		meta_group: instrument_parameters
# 		comments: Pulse repetition time. For staggered prt, also see prt_ratio.
# 		long_name: Pulse repetition time
# 	nyquist_velocity:
# 		data: <ndarray of type: float32 and shape: (426,)>
# 		units: meters_per_second
# 		meta_group: instrument_parameters
# 		comments: Unambiguous velocity
# 		long_name: Nyquist velocity
# 	prt_mode:
# 		data: <ndarray of type: |S5 and shape: (2,)>
# 		units: unitless
# 		meta_group: instrument_parameters
# 		comments: Pulsing mode Options are: "fixed", "staggered", "dual". Assumed "fixed" if missing.
# 		long_name: Pulsing mode
# 	radar_beam_width_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		long_name: Antenna beam width V polarization
# latitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_north
# 	long_name: Latitude
# 	standard_name: Latitude
# longitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_east
# 	long_name: Longitude
# 	standard_name: Longitude
# nsweeps: 2
# ngates: 950
# nrays: 426
# radar_calibration: None
# range:
# 	data: <ndarray of type: float32 and shape: (950,)>
# 	comment: Coordinate variable for range. Range to center of each bin.
# 	long_name: range_to_measurement_volume
# 	standard_name: projection_range_coordinate
# 	meters_to_center_of_first_gate: 0.0
# 	meters_between_gates: 150.0
# 	units: meters
# 	spacing_is_constant: true
# 	axis: radial_range_coordinate
# scan_rate: None
# scan_type: rhi
# sweep_end_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of last ray in sweep, 0-based
# sweep_mode:
# 	data: <ndarray of type: |S3 and shape: (2,)>
# 	units: unitless
# 	long_name: Sweep mode
# 	standard_name: sweep_mode
# 	comment: Options are: "sector", "coplane", "rhi", "vertical_pointing", "idle", "azimuth_surveillance", "elevation_surveillance", "sunscan", "pointing", "manual_ppi", "manual_rhi"
# sweep_number:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Sweep number
# 	standard_name: sweep_number
# sweep_start_ray_index:
# 	data: <ndarray of type: int32 and shape: (2,)>
# 	units: count
# 	long_name: Index of first ray in sweep, 0-based
# target_scan_rate: None
# time:
# 	data: <ndarray of type: float64 and shape: (426,)>
# 	comment: Coordinate variable for time. Time at the center of each ray, in fractional seconds since the global variable time_coverage_start
# 	long_name: time_in_seconds_since_volume_start
# 	standard_name: time
# 	units: seconds since 2014-12-18T02:59:36Z
# 	calendar: gregorian
# metadata:
# 	comment:
# 	title:
# 	Conventions: CF/Radial instrument_parameters
# 	source: MDV radar volume file created by Dsr2Vol.
# 	version: 1.3
# 	references:
# 	instrument_name: CP2, Redbank Plains, Piraq IQ data.
# 	institution:
# 	history:
